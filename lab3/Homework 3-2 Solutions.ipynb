# %% [markdown]
# *Replace this text with your own name and a brief description of what this notebook does.*

# %% [markdown]
# ## Homework 3-2
#
# NYC Open Data has a dataset of all film permits issued by the city so far for 2023: [https://data.cityofnewyork.us/City-Government/Film-Permits/tg4x-b46p](https://data.cityofnewyork.us/City-Government/Film-Permits/tg4x-b46p)
#
# The CSV file can be downloaded from the above website by:
# 1. clicking "View Data" (blue button in upper right)
# 2. clicking on "Export" (in right menu just above data)
# 3. clicking on "Download" in the pop-up that appears.
# This is same way we have downloaded data from NYC Open Data in Labs 2 and 3, but without the filtering.
#
# As in the labs, you should upload the CSV file to Jupyter Hub before starting the assignment.
#
# Write a piece of code that creates a bar chart of how many permits were issued in each category (television, film, commercial, etc.), using the `Category` column.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
permits = pd.read_csv("../../data/Film_Permits.csv")

# %%
# Check that the dataframe has been defined correctly.
permits
# Out:
#       EventID                      EventType           StartDateTime  \
# 0      722988                Shooting Permit  06/08/2023 04:00:00 AM
# 1      722865  Theater Load in and Load Outs  06/08/2023 12:01:00 AM
# 2      722224                Shooting Permit  06/08/2023 06:00:00 AM
# 3      722199                Shooting Permit  06/07/2023 09:00:00 AM
# 4      722107                Shooting Permit  06/08/2023 07:00:00 AM
# ...       ...                            ...                     ...
# 2770   677679                Shooting Permit  02/12/2023 06:00:00 AM
# 2771   677675                Shooting Permit  02/11/2023 06:00:00 AM
# 2772   677670                Shooting Permit  02/10/2023 06:00:00 AM
# 2773   677666                Shooting Permit  02/09/2023 06:00:00 AM
# 2774   677665                Shooting Permit  02/08/2023 06:00:00 AM
#
#                  EndDateTime               EnteredOn  \
# 0     06/08/2023 11:00:00 AM  06/07/2023 10:08:30 AM
# ...

# %%
category_counts = permits["Category"].value_counts()
category_counts
# Out:
# Television           1624
# Theater               438
# Film                  265
# Commercial            177
# Still Photography     121
# WEB                    98
# Documentary            28
# Student                19
# Music Video             5
# Name: Category, dtype: int64

# %%
category_counts.plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# 1. Which category had the most permits?
# 2. How many permits for films were issued?
#
# Write your answer below.

# %% [markdown]
#  1. The most popular category for permits was television.
#  2. 265 permits were issued for films.
