# %% [markdown]
# Replace this text with your own name and a brief description of what this notebook does.

# %% [markdown]
# ## Homework 1-2
#
# Write a piece of code that plots only the population of Brooklyn using the data in nycHistPop.csv from Lab 1.  You may add as many code cells as you need.
#
# Hint:  See the challenge questions in Lab 1.

# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

pop = pd.read_csv("../../data/nycHistPop.csv",skiprows = 5)

# %%
pop.plot(x = "Year", y = "Brooklyn")
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# In what years did Brooklyn's population increase the most?  Write your answer below.

# %% [markdown]
# Brooklyn's population increased the most from around 1850 to 1950.
