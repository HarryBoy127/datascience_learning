# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
movies = pd.read_csv("imdb_1000.csv")
movies
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
crime_filter = movies["genre"] == "Crime"

# %%
crime_filter
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 974    False
# 975    False
# 976    False
# 977    False
# 978     True
# Name: genre, Length: 979, dtype: bool

# %%
movies[crime_filter]
# Out:
#      star_rating                     title content_rating  genre  duration  \
# 0            9.3  The Shawshank Redemption              R  Crime       142
# 1            9.2             The Godfather              R  Crime       175
# 2            9.1    The Godfather: Part II              R  Crime       200
# 4            8.9              Pulp Fiction              R  Crime       154
# 21           8.7               City of God              R  Crime       130
# ..           ...                       ...            ...    ...       ...
# 927          7.5                     Brick              R  Crime       110
# 931          7.4              Mean Streets              R  Crime       112
# 950          7.4                     Bound              R  Crime       108
# 969          7.4       Law Abiding Citizen              R  Crime       109
# 978          7.4               Wall Street              R  Crime       126
#
#                                            actors_list
# ...

# %%
crime_movies_df = movies[crime_filter]

# %%
crime_movies_df.head(2)
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']

# %%
crime_movies = movies["star_rating"].median()

# %%
crime_movies
# Out:
# 7.8

# %%
long_filter = movies["duration"]>=180

# %%
movies[long_filter].head(2)
# Out:
#    star_rating                                          title content_rating  \
# 2          9.1                         The Godfather: Part II              R
# 7          8.9  The Lord of the Rings: The Return of the King          PG-13
#
#        genre  duration                                        actors_list
# 2      Crime       200  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 7  Adventure       201  [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...

# %%
len(movies[long_filter])
# Out:
# 33

# %%
pg13_movies_filter = movies["content_rating"] == "PG-13"
pg13_movies_filter
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 974    False
# 975    False
# 976     True
# 977    False
# 978    False
# Name: content_rating, Length: 979, dtype: bool

# %%
short_pg13_movies = movies["duration"]<= 120
short_pg13_movies
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 974     True
# 975     True
# 976    False
# 977     True
# 978    False
# Name: duration, Length: 979, dtype: bool

# %%
short_pg13_movies = movies[short_pg13_movies_filter]
short_pg13_movies.head(2)
# Out:
#     star_rating               title content_rating  genre  duration  \
# 5           8.9        12 Angry Men      NOT RATED  Drama        96
# 23          8.7  The Usual Suspects              R  Crime       106
#
#                                           actors_list
# 5   [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# 23  [u'Kevin Spacey', u'Gabriel Byrne', u'Chazz Pa...

# %%
short_pg13_movies = movies[pg13_filter & short_filter]

# %%
short_pg13_movies
# Out:
#      star_rating                        title content_rating      genre  \
# 5            8.9                 12 Angry Men      NOT RATED      Drama
# 23           8.7           The Usual Suspects              R      Crime
# 25           8.6            Life Is Beautiful          PG-13     Comedy
# 27           8.6     The Silence of the Lambs              R      Drama
# 28           8.6       Leon: The Professional              R      Crime
# ..           ...                          ...            ...        ...
# 971          7.4           Death at a Funeral              R     Comedy
# 972          7.4               Blue Valentine          NC-17      Drama
# 974          7.4                      Tootsie             PG     Comedy
# 975          7.4  Back to the Future Part III             PG  Adventure
# 977          7.4                  Poltergeist             PG     Horror
#
#      duration                                        actors_list
# ...

# %%
short_pg13_movies = movies["genre"].mode()

# %%
short_pg13_movies
# Out:
# 0    Drama
# Name: genre, dtype: object

# %%
drama_filter = movies["genre"] == "Drama"

# %%
drama_filter.head(2)
# Out:
# 0    False
# 1    False
# Name: genre, dtype: bool

# %%
top_filter = movies["star_rating"]>= 8.8

# %%
top_filter
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 974    False
# 975    False
# 976    False
# 977    False
# 978    False
# Name: star_rating, Length: 979, dtype: bool

# %%
top_or_dramas = movies[drama_filter | top_filter]

# %%
top_or_dramas
# Out:
#      star_rating                     title content_rating   genre  duration  \
# 0            9.3  The Shawshank Redemption              R   Crime       142
# 1            9.2             The Godfather              R   Crime       175
# 2            9.1    The Godfather: Part II              R   Crime       200
# 3            9.0           The Dark Knight          PG-13  Action       152
# 4            8.9              Pulp Fiction              R   Crime       154
# ..           ...                       ...            ...     ...       ...
# 958          7.4        My Sister's Keeper          PG-13   Drama       109
# 968          7.4       The English Patient              R   Drama       162
# 970          7.4               Wonder Boys              R   Drama       107
# 972          7.4            Blue Valentine          NC-17   Drama       112
# 973          7.4     The Cider House Rules          PG-13   Drama       126
#
#                                            actors_list
# ...

# %%
top_or_dramas["duration"].idxmin()
# Out:
# 389

# %%
top_or_dramas.loc[389]
# Out:
# star_rating                                                     8.0
# title                                                        Freaks
# content_rating                                              UNRATED
# genre                                                         Drama
# duration                                                         64
# actors_list       [u'Wallace Ford', u'Leila Hyams', u'Olga Bacla...
# Name: 389, dtype: object

# %% [markdown]
# 1) What's the title of the longest action movie?
#
# 2) Write a piece of code that finds the mean, variance, and standard deviation of the duration of all movies with a star rating between 7.5 and 8.5, inclusive.

# %%
movies = pd.read_csv("imdb_1000.csv")
movies.head(2)
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']

# %%
action_filter = movies["genre"] == "Action"

# %%
action_movies= movies[action_filter]

# %%
action_movies
# Out:
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                        Star Wars
# 20           8.7                                       The Matrix
# ..           ...                                              ...
# 918          7.5                                   Running Scared
# 954          7.4                                            X-Men
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# 976          7.4  Master and Commander: The Far Side of the World
#
#     content_rating   genre  duration  \
# 3            PG-13  Action       152
# 11           PG-13  Action       148
# 12              PG  Action       124
# ...

# %%
action_movies["duration"].idxmax()
# Out:
# 767

# %%
action_movies.loc[767]
# Out:
# star_rating                                                     7.6
# title                               It's a Mad, Mad, Mad, Mad World
# content_rating                                             APPROVED
# genre                                                        Action
# duration                                                        205
# actors_list       [u'Spencer Tracy', u'Milton Berle', u'Ethel Me...
# Name: 767, dtype: object
