# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
movies = pd.read_csv("imdb_1000.csv")
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
crime_filter = movies["genre"] == "Crime"

# %%
crime_filter
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 974    False
# 975    False
# 976    False
# 977    False
# 978     True
# Name: genre, Length: 979, dtype: bool

# %%
movies[crime_filter]
# Out:
#      star_rating                     title content_rating  genre  duration  \
# 0            9.3  The Shawshank Redemption              R  Crime       142
# 1            9.2             The Godfather              R  Crime       175
# 2            9.1    The Godfather: Part II              R  Crime       200
# 4            8.9              Pulp Fiction              R  Crime       154
# 21           8.7               City of God              R  Crime       130
# ..           ...                       ...            ...    ...       ...
# 927          7.5                     Brick              R  Crime       110
# 931          7.4              Mean Streets              R  Crime       112
# 950          7.4                     Bound              R  Crime       108
# 969          7.4       Law Abiding Citizen              R  Crime       109
# 978          7.4               Wall Street              R  Crime       126
#
#                                            actors_list
# ...

# %%
crime_movies_df = movies[crime_filter]

# %%
crime_movies_df.head(2)
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']

# %%
crime_movies = movies["star_rating"].median()

# %%
crime_movies
# Out:
# 7.8

# %%
long_filter = movies["duration"]>=180

# %%
movies[long_filter].head(2)
# Out:
#    star_rating                                          title content_rating  \
# 2          9.1                         The Godfather: Part II              R
# 7          8.9  The Lord of the Rings: The Return of the King          PG-13
#
#        genre  duration                                        actors_list
# 2      Crime       200  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 7  Adventure       201  [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...

# %%
len(movies[long_filter])
# Out:
# 33

# %%
pg13_movies_filter = movies["content_rating"] == "PG-13"
pg13_movies_filter
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 974    False
# 975    False
# 976     True
# 977    False
# 978    False
# Name: content_rating, Length: 979, dtype: bool

# %%
short_pg13_movies = movies["duration"]<= 120
short_pg13_movies
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 974     True
# 975     True
# 976    False
# 977     True
# 978    False
# Name: duration, Length: 979, dtype: bool

# %%
short_pg13_movies = movies[short_pg13_movies_filter]
short_pg13_movies.head(2)
# Out:
#     star_rating               title content_rating  genre  duration  \
# 5           8.9        12 Angry Men      NOT RATED  Drama        96
# 23          8.7  The Usual Suspects              R  Crime       106
#
#                                           actors_list
# 5   [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# 23  [u'Kevin Spacey', u'Gabriel Byrne', u'Chazz Pa...

# %%
short_pg13_movies = movies[pg13_filter & short_filter]

# %%
short_pg13_movies
# Out:
#      star_rating                        title content_rating      genre  \
# 5            8.9                 12 Angry Men      NOT RATED      Drama
# 23           8.7           The Usual Suspects              R      Crime
# 25           8.6            Life Is Beautiful          PG-13     Comedy
# 27           8.6     The Silence of the Lambs              R      Drama
# 28           8.6       Leon: The Professional              R      Crime
# ..           ...                          ...            ...        ...
# 971          7.4           Death at a Funeral              R     Comedy
# 972          7.4               Blue Valentine          NC-17      Drama
# 974          7.4                      Tootsie             PG     Comedy
# 975          7.4  Back to the Future Part III             PG  Adventure
# 977          7.4                  Poltergeist             PG     Horror
#
#      duration                                        actors_list
# ...

# %%
short_pg13_movies = movies["genre"].mode()
