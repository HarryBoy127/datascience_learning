# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
taxi = pd.read_csv("2021_Green_Taxi_Trip_Data.csv")
taxi.head(2)
# Out:
#    VendorID    lpep_pickup_datetime   lpep_dropoff_datetime  \
# 0         2  09/01/2021 12:00:11 AM  09/01/2021 12:01:39 AM
# 1         2  09/01/2021 12:00:26 AM  09/01/2021 12:09:38 AM
#
#   store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  passenger_count  \
# 0                  N         1.0            74            74              1.0
# 1                  N         1.0            95            56              1.0
#
#    trip_distance  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0           0.02          3.0    0.5      0.5         0.0           0.0
# 1           1.41          8.0    0.5      0.5         1.0           0.0
#
#    ehail_fee  improvement_surcharge  total_amount  payment_type  trip_type  \
# 0        NaN                    0.3           4.3           2.0        1.0
# 1        NaN                    0.3          10.3           1.0        1.0
#
#    congestion_surcharge
# 0                   0.0
# 1                   0.0

# %%
sample10 = taxi.sample(10)
sample10.head(1)
# Out:
#       VendorID    lpep_pickup_datetime   lpep_dropoff_datetime  \
# 1571         1  09/01/2021 01:37:49 PM  09/01/2021 01:46:52 PM
#
#      store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 1571                  N         1.0            65            34
#
#       passenger_count  trip_distance  fare_amount  extra  mta_tax  tip_amount  \
# 1571              1.0            1.3          7.5    0.0      0.5        2.05
#
#       tolls_amount  ehail_fee  improvement_surcharge  total_amount  \
# 1571           0.0        NaN                    0.3         10.35
#
#       payment_type  trip_type  congestion_surcharge
# 1571           1.0        1.0                   0.0

# %%
sample10 = taxi["trip_distance"].hist(bins = 50)

# %%
sample50 = taxi["trip_distance"].hist(bins = 40)

# %%
sample200 = taxi["trip_distance"].hist(bins = 30)

# %%
sample1000 = taxi["trip_distance"].hist(bins = 30)

# %%
art = pd.read_csv("Artworks.csv")
art.head(2)
# Out:
#                                                Title  \
# 0  Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1  City of Music, National Superior Conservatory ...
#
#                      Artist ConstituentID              ArtistBio Nationality  \
# 0               Otto Wagner          6210  (Austrian, 1841–1918)  (Austrian)
# 1  Christian de Portzamparc          7470    (French, born 1944)    (French)
#
#   BeginDate EndDate  Gender  Date  \
# 0    (1841)  (1918)  (Male)  1896
# 1    (1944)     (0)  (Male)  1987
#
#                                           Medium  ...  \
# 0  Ink and cut-and-pasted painted pages on paper  ...
# 1              Paint and colored pencil on print  ...
#
#                                         ThumbnailURL Circumference (cm)  \
# 0  http://www.moma.org/media/W1siZiIsIjU5NDA1Il0s...                NaN
# 1  http://www.moma.org/media/W1siZiIsIjk3Il0sWyJw...                NaN
#
# ...

# %%
male_filter = art["Gender"] == "(Male)"
female_filter = art["Gender"] == "(Female)"
nonbinary_filter = art["Gender"] == "(Non-Binary)"
no_gender_filter =  art["Gender"] == "()"
solo_art = art[male_filter | female_filter | nonbinary_filter | no_gender_filter]

# %%
solo_art.head(2)
# Out:
#                                                Title  \
# 0  Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1  City of Music, National Superior Conservatory ...
#
#                      Artist ConstituentID              ArtistBio Nationality  \
# 0               Otto Wagner          6210  (Austrian, 1841–1918)  (Austrian)
# 1  Christian de Portzamparc          7470    (French, born 1944)    (French)
#
#   BeginDate EndDate  Gender  Date  \
# 0    (1841)  (1918)  (Male)  1896
# 1    (1944)     (0)  (Male)  1987
#
#                                           Medium  ...  \
# 0  Ink and cut-and-pasted painted pages on paper  ...
# 1              Paint and colored pencil on print  ...
#
#                                         ThumbnailURL Circumference (cm)  \
# 0  http://www.moma.org/media/W1siZiIsIjU5NDA1Il0s...                NaN
# 1  http://www.moma.org/media/W1siZiIsIjk3Il0sWyJw...                NaN
#
# ...

# %%
gender_counts = solo_art["Gender"].value_counts()
gender_counts.head(2)
# Out:
# Gender
# (Male)      104235
# (Female)     17700
# Name: count, dtype: int64

# %%
gender_counts.plot (kind = "bar")
# Out:
# <Axes: xlabel='Gender'>

# %%
sample10 = solo_art.sample(10)
sample10.head(2)
# Out:
#                                 Title          Artist ConstituentID  \
# 7995  Plate (folio 20) from LABYRINTY     Jirí Balcar           303
# 4951                      Fuji Tarzan  Tadanori Yokoo          6502
#
#                   ArtistBio Nationality BeginDate EndDate  Gender  Date  \
# 7995     (Czech, 1929–1968)     (Czech)    (1929)  (1968)  (Male)  1959
# 4951  (Japanese, born 1936)  (Japanese)    (1936)     (0)  (Male)  1997
#
#                                      Medium  ...  \
# 7995  Soft ground etching, printed in black  ...
# 4951                             Silkscreen  ...
#
#                                            ThumbnailURL Circumference (cm)  \
# 7995                                                NaN                NaN
# 4951  http://www.moma.org/media/W1siZiIsIjQ0MjYiXSxb...                NaN
#
#      Depth (cm) Diameter (cm) Height (cm) Length (cm) Weight (kg)  Width (cm)  \
# 7995        NaN           NaN        24.8         NaN         NaN        15.9
# ...

# %%
gender_counts.plot (kind = "bar")
# Out:
# <Axes: xlabel='Gender'>

# %%
sample10 = solo_art.sample(10)
gender_counts10 = solo_art["Gender"].value_counts()
gender_counts10.plot(kind = "bar")
# Out:
# <Axes: xlabel='Gender'>

# %%
sample50 = solo_art.sample(50)
gender_counts50 = solo_art["Gender"].value_counts()
gender_counts50.plot(kind = "bar")
# Out:
# <Axes: xlabel='Gender'>

# %%
sample200 = solo_art.sample(50)
gender_counts200 = solo_art["Gender"].value_counts()
gender_counts200.plot(kind = "bar")
# Out:
# <Axes: xlabel='Gender'>

# %%
sample1000 = solo_art.sample(1000)
gender_counts1000 = solo_art["Gender"].value_counts()
gender_counts1000.plot(kind = "bar")
# Out:
# <Axes: xlabel='Gender'>

# %%
taxi["trip_distance"].plot(kind = "box")
# Out:
# <Axes: >

# %% [markdown]
# Assume the film permits in this dataset are the population. Write a piece of code that takes 3 different samples of size 50 and 3 different samples of size 250 from this population. For each sample, plot a bar chart of the how many permits were issued for each category (ex. film, commercial, etc.). You should end up with 6 different bar charts.

# %% [markdown]
#  How different are the 3 bar charts for the size 50 samples?

# %%
permits = pd.read_csv("Film_Permits.csv")

# %%
permits.head(2)
# Out:
#    EventID                      EventType           StartDateTime  \
# 0   739995  Theater Load in and Load Outs  09/12/2023 12:01:00 AM
# 1   739937                Shooting Permit  09/12/2023 10:00:00 AM
#
#               EndDateTime               EnteredOn  \
# 0  09/12/2023 11:59:00 PM  09/11/2023 01:54:10 PM
# 1  09/13/2023 07:00:00 PM  09/11/2023 11:10:19 AM
#
#                                       EventAgency  \
# 0  Mayor's Office of Film, Theatre & Broadcasting
# 1  Mayor's Office of Film, Theatre & Broadcasting
#
#                                          ParkingHeld    Borough  \
# 0  WEST   55 STREET between 11 AVENUE and 12 AVEN...  Manhattan
# 1  ROGERS AVENUE between MAPLE STREET and RUTLAND...   Brooklyn
#
#   CommunityBoard(s) PolicePrecinct(s) Category SubCategoryName  \
# 0                 4                18  Theater         Theater
# 1                 9                71     Film         Feature
#
#                     Country ZipCode(s)
# ...

# %%
sample50 = permits.sample(50)
category_counts = sample50["Category"].value_counts()
category_counts.plot(kind = "bar")
# Out:
# <Axes: xlabel='Category'>

# %%
sample50 = permits.sample(50)
category_counts = sample50["Category"].value_counts()
category_counts.plot(kind = "bar")
# Out:
# <Axes: xlabel='Category'>

# %%
sample50 = permits.sample(50)
category_counts = sample50["Category"].value_counts()
category_counts.plot(kind = "bar")
# Out:
# <Axes: xlabel='Category'>
