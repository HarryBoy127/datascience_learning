# %% [markdown]
# If you get an error running the import statements (first coding cell below), run the following cell (it will take 3-4 minutes) to download and install the correct version of statsmodels:

# %%
# !pip install --user 'statsmodels==0.10.0'
# Out:
# Collecting statsmodels==0.10.0
#   Using cached statsmodels-0.10.0.tar.gz (14.0 MB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.11 in /Users/harrisonajisogun/anaconda3/lib/python3.11/site-packages (from statsmodels==0.10.0) (1.24.3)
# Requirement already satisfied: scipy>=0.18 in /Users/harrisonajisogun/anaconda3/lib/python3.11/site-packages (from statsmodels==0.10.0) (1.11.1)
# Requirement already satisfied: pandas>=0.19 in /Users/harrisonajisogun/anaconda3/lib/python3.11/site-packages (from statsmodels==0.10.0) (2.0.3)
# Requirement already satisfied: patsy>=0.4.0 in /Users/harrisonajisogun/anaconda3/lib/python3.11/site-packages (from statsmodels==0.10.0) (0.5.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/harrisonajisogun/anaconda3/lib/python3.11/site-packages (from pandas>=0.19->statsmodels==0.10.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/harrisonajisogun/anaconda3/lib/python3.11/site-packages (from pandas>=0.19->statsmodels==0.10.0) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/harrisonajisogun/anaconda3/lib/python3.11/site-packages (from pandas>=0.19->statsmodels==0.10.0) (2023.3)
# Requirement already satisfied: six in /Users/harrisonajisogun/anaconda3/lib/python3.11/site-packages (from patsy>=0.4.0->statsmodels==0.10.0) (1.16.0)
# Building wheels for collected packages: statsmodels
#   Building wheel for statsmodels (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [1334 lines of output]
#       /private/var/folders/hh/nxh3r3vn2jx97bs11v7tsmd40000gn/T/pip-install-wynfbx6o/statsmodels_6fc36e66c9084b71aee8017833539fa9/setup.py:14: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#         import pkg_resources
#       /private/var/folders/hh/nxh3r3vn2jx97bs11v7tsmd40000gn/T/pip-install-wynfbx6o/statsmodels_6fc36e66c9084b71aee8017833539fa9/setup.py:50: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#         req_ver = LooseVersion(SETUP_REQUIREMENTS[key])
#       /private/var/folders/hh/nxh3r3vn2jx97bs11v7tsmd40000gn/T/pip-install-wynfbx6o/statsmodels_6fc36e66c9084b71aee8017833539fa9/setup.py:53: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#         ver = LooseVersion(mod.__version__)
#       /private/var/folders/hh/nxh3r3vn2jx97bs11v7tsmd40000gn/T/pip-install-wynfbx6o/statsmodels_6fc36e66c9084b71aee8017833539fa9/setup.py:50: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#         req_ver = LooseVersion(SETUP_REQUIREMENTS[key])
#       /Users/harrisonajisogun/anaconda3/lib/python3.11/site-packages/setuptools/config/setupcfg.py:293: _DeprecatedConfig: Deprecated config in `setup.cfg`
#       !!
#
#               ********************************************************************************
#               The license_file parameter is deprecated, use license_files instead.
#
#               This deprecation is overdue, please update your project and remove deprecated
#               calls to avoid build errors in the future.
#
#               See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#               ********************************************************************************
#
#       !!
#         parsed = self.parsers.get(option_name, lambda x: x)(value)
#       /Users/harrisonajisogun/anaconda3/lib/python3.11/site-packages/setuptools/__init__.py:84: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#       !!
#
#               ********************************************************************************
#               Requirements should be satisfied by a PEP 517 installer.
#               If you are using pip, you can try `pip install --use-pep517`.
#               ********************************************************************************
#
#       !!
#         dist.fetch_build_eggs(dist.setup_requires)
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-10.9-x86_64-cpython-311
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels
#       copying statsmodels/conftest.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels
#       copying statsmodels/_version.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels
#       copying statsmodels/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels
#       copying statsmodels/api.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/robust
#       copying statsmodels/robust/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/robust
#       copying statsmodels/robust/robust_linear_model.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/robust
#       copying statsmodels/robust/norms.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/robust
#       copying statsmodels/robust/scale.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/robust
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/interface
#       copying statsmodels/interface/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/interface
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/nonparametric
#       copying statsmodels/nonparametric/bandwidths.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/nonparametric
#       copying statsmodels/nonparametric/smoothers_lowess_old.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/nonparametric
#       copying statsmodels/nonparametric/kernel_regression.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/nonparametric
#       copying statsmodels/nonparametric/_kernel_base.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/nonparametric
#       copying statsmodels/nonparametric/kernel_density.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/nonparametric
#       copying statsmodels/nonparametric/kde.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/nonparametric
#       copying statsmodels/nonparametric/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/nonparametric
#       copying statsmodels/nonparametric/smoothers_lowess.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/nonparametric
#       copying statsmodels/nonparametric/api.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/nonparametric
#       copying statsmodels/nonparametric/kdetools.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/nonparametric
#       copying statsmodels/nonparametric/kernels.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/nonparametric
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools
#       copying statsmodels/tools/sequences.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools
#       copying statsmodels/tools/eval_measures.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools
#       copying statsmodels/tools/web.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools
#       copying statsmodels/tools/catadd.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools
#       copying statsmodels/tools/grouputils.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools
#       copying statsmodels/tools/tools.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools
#       copying statsmodels/tools/transform_model.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools
#       copying statsmodels/tools/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools
#       copying statsmodels/tools/rootfinding.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools
#       copying statsmodels/tools/linalg.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools
#       copying statsmodels/tools/sm_exceptions.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools
#       copying statsmodels/tools/print_version.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools
#       copying statsmodels/tools/_testing.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools
#       copying statsmodels/tools/parallel.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools
#       copying statsmodels/tools/testing.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools
#       copying statsmodels/tools/numdiff.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools
#       copying statsmodels/tools/data.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools
#       copying statsmodels/tools/decorators.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/compat
#       copying statsmodels/compat/pandas.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/compat
#       copying statsmodels/compat/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/compat
#       copying statsmodels/compat/numpy.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/compat
#       copying statsmodels/compat/platform.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/compat
#       copying statsmodels/compat/scipy.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/compat
#       copying statsmodels/compat/python.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/compat
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/multivariate
#       copying statsmodels/multivariate/multivariate_ols.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/multivariate
#       copying statsmodels/multivariate/manova.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/multivariate
#       copying statsmodels/multivariate/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/multivariate
#       copying statsmodels/multivariate/api.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/multivariate
#       copying statsmodels/multivariate/plots.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/multivariate
#       copying statsmodels/multivariate/pca.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/multivariate
#       copying statsmodels/multivariate/factor.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/multivariate
#       copying statsmodels/multivariate/cancorr.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/multivariate
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/discrete
#       copying statsmodels/discrete/discrete_model.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/discrete
#       copying statsmodels/discrete/conditional_models.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/discrete
#       copying statsmodels/discrete/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/discrete
#       copying statsmodels/discrete/discrete_margins.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/discrete
#       copying statsmodels/discrete/_diagnostics_count.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/discrete
#       copying statsmodels/discrete/count_model.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/discrete
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets
#       copying statsmodels/datasets/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets
#       copying statsmodels/datasets/utils.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets
#       copying statsmodels/datasets/template_data.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tests
#       copying statsmodels/tests/test_package.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tests
#       copying statsmodels/tests/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tests
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/miscmodels
#       copying statsmodels/miscmodels/nonlinls.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/miscmodels
#       copying statsmodels/miscmodels/tmodel.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/miscmodels
#       copying statsmodels/miscmodels/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/miscmodels
#       copying statsmodels/miscmodels/api.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/miscmodels
#       copying statsmodels/miscmodels/try_mlecov.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/miscmodels
#       copying statsmodels/miscmodels/count.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/miscmodels
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/iolib
#       copying statsmodels/iolib/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/iolib
#       copying statsmodels/iolib/api.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/iolib
#       copying statsmodels/iolib/openfile.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/iolib
#       copying statsmodels/iolib/summary.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/iolib
#       copying statsmodels/iolib/tableformatting.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/iolib
#       copying statsmodels/iolib/table.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/iolib
#       copying statsmodels/iolib/stata_summary_examples.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/iolib
#       copying statsmodels/iolib/smpickle.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/iolib
#       copying statsmodels/iolib/summary2.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/iolib
#       copying statsmodels/iolib/foreign.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/iolib
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/gam
#       copying statsmodels/gam/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/gam
#       copying statsmodels/gam/smooth_basis.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/gam
#       copying statsmodels/gam/api.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/gam
#       copying statsmodels/gam/generalized_additive_model.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/gam
#       copying statsmodels/gam/gam_penalties.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/gam
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/resampling
#       copying statsmodels/resampling/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/resampling
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/sandbox
#       copying statsmodels/sandbox/sysreg.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/sandbox
#       copying statsmodels/sandbox/bspline.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/sandbox
#       copying statsmodels/sandbox/formula.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/sandbox
#       copying statsmodels/sandbox/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/sandbox
#       copying statsmodels/sandbox/infotheo.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/sandbox
#       copying statsmodels/sandbox/utils_old.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/sandbox
#       copying statsmodels/sandbox/predict_functional.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/sandbox
#       copying statsmodels/sandbox/pca.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/sandbox
#       copying statsmodels/sandbox/mle.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/sandbox
#       copying statsmodels/sandbox/contrast_old.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/sandbox
#       copying statsmodels/sandbox/rls.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/sandbox
#       copying statsmodels/sandbox/multilinear.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/sandbox
#       copying statsmodels/sandbox/gam.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/sandbox
#       copying statsmodels/sandbox/descstats.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/sandbox
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/imputation
#       copying statsmodels/imputation/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/imputation
#       copying statsmodels/imputation/ros.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/imputation
#       copying statsmodels/imputation/bayes_mi.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/imputation
#       copying statsmodels/imputation/mice.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/imputation
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/formula
#       copying statsmodels/formula/formulatools.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/formula
#       copying statsmodels/formula/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/formula
#       copying statsmodels/formula/api.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/formula
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/genmod
#       copying statsmodels/genmod/_tweedie_compound_poisson.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/genmod
#       copying statsmodels/genmod/cov_struct.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/genmod
#       copying statsmodels/genmod/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/genmod
#       copying statsmodels/genmod/api.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/genmod
#       copying statsmodels/genmod/generalized_estimating_equations.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/genmod
#       copying statsmodels/genmod/qif.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/genmod
#       copying statsmodels/genmod/bayes_mixed_glm.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/genmod
#       copying statsmodels/genmod/_prediction.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/genmod
#       copying statsmodels/genmod/generalized_linear_model.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/genmod
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa
#       copying statsmodels/tsa/arima_process.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa
#       copying statsmodels/tsa/arima_model.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa
#       copying statsmodels/tsa/descriptivestats.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa
#       copying statsmodels/tsa/stattools.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa
#       copying statsmodels/tsa/x13.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa
#       copying statsmodels/tsa/holtwinters.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa
#       copying statsmodels/tsa/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa
#       copying statsmodels/tsa/_bds.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa
#       copying statsmodels/tsa/tsatools.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa
#       copying statsmodels/tsa/seasonal.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa
#       copying statsmodels/tsa/api.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa
#       copying statsmodels/tsa/coint_tables.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa
#       copying statsmodels/tsa/varma_process.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa
#       copying statsmodels/tsa/adfvalues.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa
#       copying statsmodels/tsa/ar_model.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa
#       copying statsmodels/tsa/arma_mle.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa
#       copying statsmodels/tsa/mlemodel.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/regression
#       copying statsmodels/regression/recursive_ls.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/regression
#       copying statsmodels/regression/_tools.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/regression
#       copying statsmodels/regression/feasible_gls.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/regression
#       copying statsmodels/regression/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/regression
#       copying statsmodels/regression/process_regression.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/regression
#       copying statsmodels/regression/quantile_regression.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/regression
#       copying statsmodels/regression/linear_model.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/regression
#       copying statsmodels/regression/dimred.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/regression
#       copying statsmodels/regression/mixed_linear_model.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/regression
#       copying statsmodels/regression/_prediction.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/regression
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/graphics
#       copying statsmodels/graphics/plot_grids.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/graphics
#       copying statsmodels/graphics/dotplots.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/graphics
#       copying statsmodels/graphics/plottools.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/graphics
#       copying statsmodels/graphics/tsaplots.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/graphics
#       copying statsmodels/graphics/tukeyplot.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/graphics
#       copying statsmodels/graphics/agreement.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/graphics
#       copying statsmodels/graphics/_regressionplots_doc.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/graphics
#       copying statsmodels/graphics/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/graphics
#       copying statsmodels/graphics/gofplots.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/graphics
#       copying statsmodels/graphics/regressionplots.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/graphics
#       copying statsmodels/graphics/api.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/graphics
#       copying statsmodels/graphics/functional.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/graphics
#       copying statsmodels/graphics/utils.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/graphics
#       copying statsmodels/graphics/correlation.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/graphics
#       copying statsmodels/graphics/boxplots.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/graphics
#       copying statsmodels/graphics/factorplots.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/graphics
#       copying statsmodels/graphics/mosaicplot.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/graphics
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/emplike
#       copying statsmodels/emplike/elanova.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/emplike
#       copying statsmodels/emplike/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/emplike
#       copying statsmodels/emplike/originregress.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/emplike
#       copying statsmodels/emplike/api.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/emplike
#       copying statsmodels/emplike/aft_el.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/emplike
#       copying statsmodels/emplike/descriptive.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/emplike
#       copying statsmodels/emplike/elregress.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/emplike
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/duration
#       copying statsmodels/duration/_kernel_estimates.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/duration
#       copying statsmodels/duration/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/duration
#       copying statsmodels/duration/api.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/duration
#       copying statsmodels/duration/survfunc.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/duration
#       copying statsmodels/duration/hazard_regression.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/duration
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/distributions
#       copying statsmodels/distributions/mixture_rvs.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/distributions
#       copying statsmodels/distributions/edgeworth.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/distributions
#       copying statsmodels/distributions/empirical_distribution.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/distributions
#       copying statsmodels/distributions/discrete.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/distributions
#       copying statsmodels/distributions/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/distributions
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/base
#       copying statsmodels/base/l1_solvers_common.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/base
#       copying statsmodels/base/l1_cvxopt.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/base
#       copying statsmodels/base/elastic_net.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/base
#       copying statsmodels/base/wrapper.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/base
#       copying statsmodels/base/_screening.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/base
#       copying statsmodels/base/distributed_estimation.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/base
#       copying statsmodels/base/_penalized.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/base
#       copying statsmodels/base/covtype.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/base
#       copying statsmodels/base/_penalties.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/base
#       copying statsmodels/base/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/base
#       copying statsmodels/base/l1_slsqp.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/base
#       copying statsmodels/base/model.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/base
#       copying statsmodels/base/_parameter_inference.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/base
#       copying statsmodels/base/transform.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/base
#       copying statsmodels/base/optimizer.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/base
#       copying statsmodels/base/_constraints.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/base
#       copying statsmodels/base/data.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/base
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats
#       copying statsmodels/stats/descriptivestats.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats
#       copying statsmodels/stats/stattools.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats
#       copying statsmodels/stats/tabledist.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats
#       copying statsmodels/stats/multivariate_tools.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats
#       copying statsmodels/stats/anova.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats
#       copying statsmodels/stats/correlation_tools.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats
#       copying statsmodels/stats/_knockoff.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats
#       copying statsmodels/stats/moment_helpers.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats
#       copying statsmodels/stats/_diagnostic_other.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats
#       copying statsmodels/stats/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats
#       copying statsmodels/stats/weightstats.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats
#       copying statsmodels/stats/contingency_tables.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats
#       copying statsmodels/stats/gof.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats
#       copying statsmodels/stats/_adnorm.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats
#       copying statsmodels/stats/sandwich_covariance.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats
#       copying statsmodels/stats/proportion.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats
#       copying statsmodels/stats/api.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats
#       copying statsmodels/stats/diagnostic.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats
#       copying statsmodels/stats/outliers_influence.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats
#       copying statsmodels/stats/multitest.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats
#       copying statsmodels/stats/regularized_covariance.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats
#       copying statsmodels/stats/mediation.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats
#       copying statsmodels/stats/knockoff_regeffects.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats
#       copying statsmodels/stats/multicomp.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats
#       copying statsmodels/stats/_lilliefors.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats
#       copying statsmodels/stats/power.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats
#       copying statsmodels/stats/base.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats
#       copying statsmodels/stats/inter_rater.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats
#       copying statsmodels/stats/contrast.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/src
#       copying statsmodels/src/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/src
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/robust/tests
#       copying statsmodels/robust/tests/test_rlm.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/robust/tests
#       copying statsmodels/robust/tests/test_scale.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/robust/tests
#       copying statsmodels/robust/tests/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/robust/tests
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/robust/tests/results
#       copying statsmodels/robust/tests/results/results_rlm.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/robust/tests/results
#       copying statsmodels/robust/tests/results/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/robust/tests/results
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/nonparametric/tests
#       copying statsmodels/nonparametric/tests/test_kde.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/nonparametric/tests
#       copying statsmodels/nonparametric/tests/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/nonparametric/tests
#       copying statsmodels/nonparametric/tests/test_kernels.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/nonparametric/tests
#       copying statsmodels/nonparametric/tests/test_lowess.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/nonparametric/tests
#       copying statsmodels/nonparametric/tests/test_kernel_regression.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/nonparametric/tests
#       copying statsmodels/nonparametric/tests/test_bandwidths.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/nonparametric/tests
#       copying statsmodels/nonparametric/tests/test_kernel_density.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/nonparametric/tests
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/nonparametric/tests/results
#       copying statsmodels/nonparametric/tests/results/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/nonparametric/tests/results
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools/tests
#       copying statsmodels/tools/tests/test_linalg.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools/tests
#       copying statsmodels/tools/tests/test_eval_measures.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools/tests
#       copying statsmodels/tools/tests/test_decorators.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools/tests
#       copying statsmodels/tools/tests/test_rootfinding.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools/tests
#       copying statsmodels/tools/tests/test_web.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools/tests
#       copying statsmodels/tools/tests/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools/tests
#       copying statsmodels/tools/tests/test_grouputils.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools/tests
#       copying statsmodels/tools/tests/test_parallel.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools/tests
#       copying statsmodels/tools/tests/test_sequences.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools/tests
#       copying statsmodels/tools/tests/test_catadd.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools/tests
#       copying statsmodels/tools/tests/test_data.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools/tests
#       copying statsmodels/tools/tests/test_numdiff.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools/tests
#       copying statsmodels/tools/tests/test_tools.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools/tests
#       copying statsmodels/tools/tests/test_transform_model.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools/tests
#       copying statsmodels/tools/tests/test_testing.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tools/tests
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/compat/tests
#       copying statsmodels/compat/tests/test_itercompat.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/compat/tests
#       copying statsmodels/compat/tests/test_scipy_compat.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/compat/tests
#       copying statsmodels/compat/tests/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/compat/tests
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/multivariate/tests
#       copying statsmodels/multivariate/tests/test_factor.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/multivariate/tests
#       copying statsmodels/multivariate/tests/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/multivariate/tests
#       copying statsmodels/multivariate/tests/test_cancorr.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/multivariate/tests
#       copying statsmodels/multivariate/tests/test_manova.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/multivariate/tests
#       copying statsmodels/multivariate/tests/test_multivariate_ols.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/multivariate/tests
#       copying statsmodels/multivariate/tests/test_ml_factor.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/multivariate/tests
#       copying statsmodels/multivariate/tests/test_pca.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/multivariate/tests
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/multivariate/factor_rotation
#       copying statsmodels/multivariate/factor_rotation/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/multivariate/factor_rotation
#       copying statsmodels/multivariate/factor_rotation/_wrappers.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/multivariate/factor_rotation
#       copying statsmodels/multivariate/factor_rotation/_analytic_rotation.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/multivariate/factor_rotation
#       copying statsmodels/multivariate/factor_rotation/_gpa_rotation.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/multivariate/factor_rotation
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/multivariate/tests/results
#       copying statsmodels/multivariate/tests/results/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/multivariate/tests/results
#       copying statsmodels/multivariate/tests/results/datamlw.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/multivariate/tests/results
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/multivariate/factor_rotation/tests
#       copying statsmodels/multivariate/factor_rotation/tests/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/multivariate/factor_rotation/tests
#       copying statsmodels/multivariate/factor_rotation/tests/test_rotation.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/multivariate/factor_rotation/tests
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/discrete/tests
#       copying statsmodels/discrete/tests/test_discrete.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/discrete/tests
#       copying statsmodels/discrete/tests/test_sandwich_cov.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/discrete/tests
#       copying statsmodels/discrete/tests/test_diagnostic.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/discrete/tests
#       copying statsmodels/discrete/tests/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/discrete/tests
#       copying statsmodels/discrete/tests/test_conditional.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/discrete/tests
#       copying statsmodels/discrete/tests/test_margins.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/discrete/tests
#       copying statsmodels/discrete/tests/test_constrained.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/discrete/tests
#       copying statsmodels/discrete/tests/test_count_model.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/discrete/tests
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/discrete/tests/results
#       copying statsmodels/discrete/tests/results/results_count_robust_cluster.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/discrete/tests/results
#       copying statsmodels/discrete/tests/results/results_discrete.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/discrete/tests/results
#       copying statsmodels/discrete/tests/results/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/discrete/tests/results
#       copying statsmodels/discrete/tests/results/results_glm_logit_constrained.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/discrete/tests/results
#       copying statsmodels/discrete/tests/results/results_count_margins.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/discrete/tests/results
#       copying statsmodels/discrete/tests/results/results_poisson_constrained.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/discrete/tests/results
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/statecrime
#       copying statsmodels/datasets/statecrime/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/statecrime
#       copying statsmodels/datasets/statecrime/data.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/statecrime
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/committee
#       copying statsmodels/datasets/committee/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/committee
#       copying statsmodels/datasets/committee/data.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/committee
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/engel
#       copying statsmodels/datasets/engel/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/engel
#       copying statsmodels/datasets/engel/data.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/engel
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/strikes
#       copying statsmodels/datasets/strikes/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/strikes
#       copying statsmodels/datasets/strikes/data.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/strikes
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/cpunish
#       copying statsmodels/datasets/cpunish/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/cpunish
#       copying statsmodels/datasets/cpunish/data.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/cpunish
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/anes96
#       copying statsmodels/datasets/anes96/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/anes96
#       copying statsmodels/datasets/anes96/data.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/anes96
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/heart
#       copying statsmodels/datasets/heart/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/heart
#       copying statsmodels/datasets/heart/data.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/heart
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/modechoice
#       copying statsmodels/datasets/modechoice/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/modechoice
#       copying statsmodels/datasets/modechoice/data.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/modechoice
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/randhie
#       copying statsmodels/datasets/randhie/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/randhie
#       copying statsmodels/datasets/randhie/data.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/randhie
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/copper
#       copying statsmodels/datasets/copper/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/copper
#       copying statsmodels/datasets/copper/data.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/copper
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/fertility
#       copying statsmodels/datasets/fertility/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/fertility
#       copying statsmodels/datasets/fertility/data.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/fertility
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/tests
#       copying statsmodels/datasets/tests/test_utils.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/tests
#       copying statsmodels/datasets/tests/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/tests
#       copying statsmodels/datasets/tests/test_data.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/tests
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/sunspots
#       copying statsmodels/datasets/sunspots/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/sunspots
#       copying statsmodels/datasets/sunspots/data.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/sunspots
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/china_smoking
#       copying statsmodels/datasets/china_smoking/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/china_smoking
#       copying statsmodels/datasets/china_smoking/data.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/china_smoking
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/star98
#       copying statsmodels/datasets/star98/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/star98
#       copying statsmodels/datasets/star98/data.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/star98
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/macrodata
#       copying statsmodels/datasets/macrodata/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/macrodata
#       copying statsmodels/datasets/macrodata/data.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/macrodata
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/scotland
#       copying statsmodels/datasets/scotland/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/scotland
#       copying statsmodels/datasets/scotland/data.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/scotland
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/longley
#       copying statsmodels/datasets/longley/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/longley
#       copying statsmodels/datasets/longley/data.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/longley
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/spector
#       copying statsmodels/datasets/spector/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/spector
#       copying statsmodels/datasets/spector/data.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/spector
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/cancer
#       copying statsmodels/datasets/cancer/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/cancer
#       copying statsmodels/datasets/cancer/data.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/cancer
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/fair
#       copying statsmodels/datasets/fair/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/fair
#       copying statsmodels/datasets/fair/data.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/fair
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/nile
#       copying statsmodels/datasets/nile/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/nile
#       copying statsmodels/datasets/nile/data.py -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/nile
#       creating build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/datasets/ccard
# ...
#       copying statsmodels/tsa/vector_ar/tests/results/e2.dat -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/vector_ar/tests/results
#       copying statsmodels/tsa/vector_ar/tests/results/e1.dat -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/vector_ar/tests/results
#       copying statsmodels/tsa/vector_ar/tests/Matlab_results/test_coint.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/vector_ar/tests/Matlab_results
#       copying statsmodels/tsa/regime_switching/tests/results/results_predict_fedfunds.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/regime_switching/tests/results
#       copying statsmodels/tsa/regime_switching/tests/results/results_predict_rgnp.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/regime_switching/tests/results
#       copying statsmodels/tsa/regime_switching/tests/results/mar_filardo.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/regime_switching/tests/results
#       copying statsmodels/tsa/tests/results/arima212_forecast.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/tests/results
#       copying statsmodels/tsa/tests/results/results_ar_forecast_mle_dynamic.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/tests/results
#       copying statsmodels/tsa/tests/results/results_arima_exog_forecasts_css.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/tests/results
#       copying statsmodels/tsa/tests/results/bds_results.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/tests/results
#       copying statsmodels/tsa/tests/results/bds_data.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/tests/results
#       copying statsmodels/tsa/tests/results/y_arma_data.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/tests/results
#       copying statsmodels/tsa/tests/results/resids_exact_nc.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/tests/results
#       copying statsmodels/tsa/tests/results/housing-data.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/tests/results
#       copying statsmodels/tsa/tests/results/results_arima_forecasts_all_css.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/tests/results
#       copying statsmodels/tsa/tests/results/results_arima_exog_forecasts_mle.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/tests/results
#       copying statsmodels/tsa/tests/results/results_arima_forecasts_all_css_diff.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/tests/results
#       copying statsmodels/tsa/tests/results/yhat_css_nc.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/tests/results
#       copying statsmodels/tsa/tests/results/results_arima_forecasts_all_mle_diff.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/tests/results
#       copying statsmodels/tsa/tests/results/yhat_css_c.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/tests/results
#       copying statsmodels/tsa/tests/results/results_arima_forecasts.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/tests/results
#       copying statsmodels/tsa/tests/results/results_corrgram.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/tests/results
#       copying statsmodels/tsa/tests/results/yhat_exact_c.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/tests/results
#       copying statsmodels/tsa/tests/results/ARMLEConstantPredict.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/tests/results
#       copying statsmodels/tsa/tests/results/results_arma_forecasts.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/tests/results
#       copying statsmodels/tsa/tests/results/results_arima_forecasts_all_mle.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/tests/results
#       copying statsmodels/tsa/tests/results/yhat_exact_nc.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/tests/results
#       copying statsmodels/tsa/tests/results/resids_css_nc.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/tests/results
#       copying statsmodels/tsa/tests/results/resids_exact_c.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/tests/results
#       copying statsmodels/tsa/tests/results/resids_css_c.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/tests/results
#       copying statsmodels/tsa/tests/results/arima111_forecasts.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/tests/results
#       copying statsmodels/tsa/tests/results/AROLSConstantPredict.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/tests/results
#       copying statsmodels/tsa/tests/results/AROLSNoConstantPredict.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/tests/results
#       copying statsmodels/tsa/tests/results/lutkepohl2.dta -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/tests/results
#       copying statsmodels/regression/tests/results/pastes.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/regression/tests/results
#       copying statsmodels/regression/tests/results/lme08.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/regression/tests/results
#       copying statsmodels/regression/tests/results/lme09.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/regression/tests/results
#       copying statsmodels/regression/tests/results/dietox.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/regression/tests/results
#       copying statsmodels/regression/tests/results/lme07.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/regression/tests/results
#       copying statsmodels/regression/tests/results/results_rls_stata.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/regression/tests/results
#       copying statsmodels/regression/tests/results/lme06.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/regression/tests/results
#       copying statsmodels/regression/tests/results/lasso_data.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/regression/tests/results
#       copying statsmodels/regression/tests/results/lme04.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/regression/tests/results
#       copying statsmodels/regression/tests/results/lme10.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/regression/tests/results
#       copying statsmodels/regression/tests/results/lme11.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/regression/tests/results
#       copying statsmodels/regression/tests/results/lme05.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/regression/tests/results
#       copying statsmodels/regression/tests/results/results_rls_R.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/regression/tests/results
#       copying statsmodels/regression/tests/results/lme01.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/regression/tests/results
#       copying statsmodels/regression/tests/results/theil_textile_predict.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/regression/tests/results
#       copying statsmodels/regression/tests/results/lme00.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/regression/tests/results
#       copying statsmodels/regression/tests/results/lme02.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/regression/tests/results
#       copying statsmodels/regression/tests/results/lme03.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/regression/tests/results
#       copying statsmodels/regression/tests/results/leverage_influence_ols_nostars.txt -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/regression/tests/results
#       copying statsmodels/duration/tests/results/bmt_results.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/duration/tests/results
#       copying statsmodels/duration/tests/results/bmt.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/duration/tests/results
#       copying statsmodels/duration/tests/results/survival_data_1000_10.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/duration/tests/results
#       copying statsmodels/duration/tests/results/survival_data_20_1.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/duration/tests/results
#       copying statsmodels/duration/tests/results/survival_data_50_2.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/duration/tests/results
#       copying statsmodels/duration/tests/results/survival_data_100_5.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/duration/tests/results
#       copying statsmodels/duration/tests/results/survival_data_50_1.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/duration/tests/results
#       copying statsmodels/stats/libqsturng/CH.r -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats/libqsturng
#       copying statsmodels/stats/libqsturng/LICENSE.txt -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats/libqsturng
#       copying statsmodels/stats/tests/test_data.txt -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats/tests
#       copying statsmodels/stats/libqsturng/tests/bootleg.dat -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats/libqsturng/tests
#       copying statsmodels/stats/tests/results/bootleg.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats/tests/results
#       copying statsmodels/stats/tests/results/framing.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats/tests/results
#       copying statsmodels/stats/tests/results/binary_constrict.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats/tests/results
#       copying statsmodels/stats/tests/results/influence_measures_bool_R.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats/tests/results
#       copying statsmodels/stats/tests/results/results_influence_logit.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats/tests/results
#       copying statsmodels/stats/tests/results/influence_measures_R.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats/tests/results
#       copying statsmodels/stats/tests/results/wspec1.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats/tests/results
#       copying statsmodels/stats/tests/results/wspec2.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats/tests/results
#       copying statsmodels/stats/tests/results/wspec3.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats/tests/results
#       copying statsmodels/stats/tests/results/wspec4.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats/tests/results
#       copying statsmodels/stats/tests/results/contingency_table_r_results.csv -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats/tests/results
#       copying statsmodels/stats/tests/results/influence_lsdiag_R.json -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats/tests/results
#       copying statsmodels/stats/tests/results/data.dat -> build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/stats/tests/results
#       UPDATING build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/_version.py
#       set build/lib.macosx-10.9-x86_64-cpython-311/statsmodels/_version.py to '0.10.0'
#       running build_ext
#       /private/var/folders/hh/nxh3r3vn2jx97bs11v7tsmd40000gn/T/pip-install-wynfbx6o/statsmodels_6fc36e66c9084b71aee8017833539fa9/setup.py:201: DeprecationWarning:
#
#         `numpy.distutils` is deprecated since NumPy 1.23.0, as a result
#         of the deprecation of `distutils` itself. It will be removed for
#         Python >= 3.12. For older Python versions it will remain present.
#         It is recommended to use `setuptools < 60.0` for those Python versions.
#         For more details, see:
#           https://numpy.org/devdocs/reference/distutils_status_migration.html
#
#
#         from numpy.distutils.misc_util import get_info
#       error: Command "clang -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/harrisonajisogun/anaconda3/include -fPIC -O2 -isystem /Users/harrisonajisogun/anaconda3/include -DCYTHON_TRACE_NOGIL=0 -I/Users/harrisonajisogun/anaconda3/lib/python3.11/site-packages/numpy/core/include -I/Users/harrisonajisogun/anaconda3/lib/python3.11/site-packages/numpy/core/include -I/Users/harrisonajisogun/anaconda3/include/python3.11 -c statsmodels/tsa/_exponential_smoothers.c -o build/temp.macosx-10.9-x86_64-cpython-311/statsmodels/tsa/_exponential_smoothers.o" failed with exit status 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for statsmodels
#   Running setup.py clean for statsmodels
#   error: subprocess-exited-with-error
#
#   × python setup.py clean did not run successfully.
#   │ exit code: 1
#   ╰─> [42 lines of output]
#       /private/var/folders/hh/nxh3r3vn2jx97bs11v7tsmd40000gn/T/pip-install-wynfbx6o/statsmodels_6fc36e66c9084b71aee8017833539fa9/setup.py:14: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#         import pkg_resources
#       /private/var/folders/hh/nxh3r3vn2jx97bs11v7tsmd40000gn/T/pip-install-wynfbx6o/statsmodels_6fc36e66c9084b71aee8017833539fa9/setup.py:50: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#         req_ver = LooseVersion(SETUP_REQUIREMENTS[key])
#       /private/var/folders/hh/nxh3r3vn2jx97bs11v7tsmd40000gn/T/pip-install-wynfbx6o/statsmodels_6fc36e66c9084b71aee8017833539fa9/setup.py:53: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#         ver = LooseVersion(mod.__version__)
#       /private/var/folders/hh/nxh3r3vn2jx97bs11v7tsmd40000gn/T/pip-install-wynfbx6o/statsmodels_6fc36e66c9084b71aee8017833539fa9/setup.py:50: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#         req_ver = LooseVersion(SETUP_REQUIREMENTS[key])
#       /Users/harrisonajisogun/anaconda3/lib/python3.11/site-packages/setuptools/config/setupcfg.py:293: _DeprecatedConfig: Deprecated config in `setup.cfg`
#       !!
#
#               ********************************************************************************
#               The license_file parameter is deprecated, use license_files instead.
#
#               This deprecation is overdue, please update your project and remove deprecated
#               calls to avoid build errors in the future.
#
#               See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#               ********************************************************************************
#
#       !!
#         parsed = self.parsers.get(option_name, lambda x: x)(value)
#       /Users/harrisonajisogun/anaconda3/lib/python3.11/site-packages/setuptools/__init__.py:84: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#       !!
#
#               ********************************************************************************
#               Requirements should be satisfied by a PEP 517 installer.
#               If you are using pip, you can try `pip install --use-pep517`.
#               ********************************************************************************
#
#       !!
#         dist.fetch_build_eggs(dist.setup_requires)
#       running clean
#
#
#       python setup.py clean is not supported.
#
#       Use one of:
#
#       * `git clean -xdf` to clean all untracked files
#       * `git clean -Xdf` to clean untracked files ignored by .gitignore
#
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed cleaning build dir for statsmodels
# Failed to build statsmodels
# ERROR: Could not build wheels for statsmodels, which is required to install pyproject.toml-based projects

# %% [markdown]
# Once it has finished running (the `[*]` changes to number), restart the kernel by clicking on "Kernel > Restart" in the top menu.  Rerun the import statements and there should no longer be an error.

# %% [markdown]
# # Lab 21 - Simple linear regression
#
# We will use the dataset with information about the labor market for recent college graduates from Lab 20.  You can also download the CSV file from Blackboard.
#
# ### 21.1 Loading and cleaning the data
#
# We will use a new library in this lab, called statsmodels. Import this and our other usual libraries so we can use them in our code.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import statsmodels.formula.api as smf

# %% [markdown]
# As in Lab 20 we need to read our CSV file into a dataframe and clean it.
#
# Load the data in the dataframe `labor`, remembering to skip the non-data rows at the start and end of the file.

# %%
labor = pd.read_csv("")

# %% [markdown]
# Display your `labor` dataframe below to check it was created properly.

# %% [markdown]
# To make things easier, we will rename the columns to shorter names without spaces.

# %%
labor.columns = ["major","unemployment","underemployment","early","mid","graduate"]

# %% [markdown]
# Next we need to remove the commas from the `early` and `mid` columns, and change the column type to float, as in Lab 20.

# %% [markdown]
# <details> <summary>Answer:</summary>
# <code>labor["early"] = labor["early"].str.replace(",","").astype(float)
# labor["mid"] = labor["mid"].str.replace(",","").astype(float)</code>
# </details>
#
# Check that this code worked correctly by displaying `labor` again:

# %% [markdown]
# ### 21.2 Simple linear regression
#
# Recall from Lab 20 that the columns `early` (which was `Median Wage Early Career`) and `mid` (which was `Median Wage Mid-Career`) were the most correlated.
#
# Let's remind ourselves what the relationship looked like by plotting a scatter plot with `early` on the x axis and `mid` on the y axis.

# %% [markdown]
# <details> <summary>Pattern:</summary>
# <code>df.plot.scatter(x = "column name 1", y = "column name 2")</code>
# </details>
#
# We can perform linear regression with the following code, which does not display anything:

# %%
lm = smf.ols(formula = 'mid ~ early', data = labor).fit()

# %% [markdown]
# The formula is always `dependent_variable ~ independent_variable`, and in this form, the variable names, which are the column names, cannot have spaces in them or else we need to use `Q('variable name with spaces')`.
#
# All the information about the linear model is stored in the variable `lm`.  To see this information, type and run  `lm.summary()` below.

# %% [markdown]
# This is a lot of information!  We will only focus on a few of the numbers.  The coefficients for the regression line can be found in the middle section, under the column `coef`:
# $\beta_0 = 6394.6948$ and $\beta_1 = 1.4452$.
#
# Thus, the regression line equation is $y = 1.4452x + 6394.6948$
#
# You can also get the coefficients by typing `lm.params`:

# %% [markdown]
# ### 21.3  Plotting the regression line and residuals
#
# We will use Seaborn to plot the regression line on the scatterplot in one step.  Type and run the code: `sns.regplot(x = 'early',y = 'mid', data = labor)`

# %% [markdown]
# To further check if the linear model is a good fit for the data, we can plot the residuals to see if they have a normal distribution.  To get the residuals, type `lm.resid` below.

# %% [markdown]
# Can you figure out how to plot the residuals as a histogram?  They are already stored as a Pandas Series.

# %% [markdown]
# Does the distribution of the residuals look normal?  Can you find the residual outlier on the scatter plot?  Can you figure out what major that is?  We looked at how to identify outliers in Lab 5.

# %% [markdown]
# <details> <summary>Answer:</summary>
# We find the row of the largest residual<br>
# <code>max_row = lm.resid.idxmax()</code><br>
# and then display that row:<br>
# <code>labor.loc[max_row]</code>
# </details>
#
# ### 21.4 Regression line: underemployment vs. median wage early career
#
# The next two most correlated columns were `underemployment` and `early`. Compute the linear regression model with `underemployment` as the independent variable and `early` as the dependent variable.

# %% [markdown]
# <details> <summary>Pattern:</summary>
# <code>lm_name = smf.ols(formula = 'dependent_variable ~ indepedent_variable', data = df_name).fit()</code>
# </details>
#
# Display a summary of your linear regression model.

# %% [markdown]
# <details> <summary>Pattern:</summary>
# <code>lm_name.summary()</code>
# </details>
#
# What is the equation for the linear regression line?
#
# Use the Seaborn package to plot the scatter plot of underemployment vs. median wage early career with the regression line.

# %% [markdown]
# <details> <summary>Pattern:</summary>
# <code>sns.regplot(x = 'independent_variable' ,y = 'dependent_variable', data = df_name)</code>
# </details>
#
# Plot the residuals as a histogram.

# %% [markdown]
# <details> <summary>Pattern:</summary>
# <code>pd.Series(lm_name.resid).hist()</code>
# </details>
#
# Is the distribution of the residuals roughly normal?  Is your linear regression model a good representation of the relationship between underemployment and median wage early career?
#
# ### Challenges
# - In the green taxi trip data, what is the correlation between trip distance and fare amount?  Compute the linear regression line with trip distance as the independent variable and fare amount as the dependent variable.  Find the equation for the regression line, plot the scatterplot with the line, and check if the residuals are normally distributed.
