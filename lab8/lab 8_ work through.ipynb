# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# show all columns when displaying the dataframe
pd.set_option('display.max_columns', None)

# %%
calls = pd.read_csv("311_Service_Requests_from_2010_to_Present.csv")

# %%
calls.head(2)
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    58823685  09/15/2023 11:59:57 PM  09/18/2023 11:39:38 AM  DOHMH
# 1    58821637  09/15/2023 11:59:44 PM  09/16/2023 12:25:10 AM   NYPD
#
#                                Agency Name           Complaint Type  \
# 0  Department of Health and Mental Hygiene                   Rodent
# 1          New York City Police Department  Noise - Street/Sidewalk
#
#          Descriptor            Location Type  Incident Zip  \
# 0      Rat Sighting  3+ Family Apt. Building       11213.0
# 1  Loud Music/Party          Street/Sidewalk       10034.0
#
#         Incident Address        Street Name      Cross Street 1  \
# 0      1702 UNION STREET       UNION STREET  SCHENECTADY AVENUE
# 1  108 PARK TERRACE EAST  PARK TERRACE EAST    WEST  217 STREET
#
#      Cross Street 2 Intersection Street 1 Intersection Street 2 Address Type  \
# 0      UTICA AVENUE    SCHENECTADY AVENUE          UTICA AVENUE      ADDRESS
# ...

# %%
complaint_counts = calls["Complaint Type"].value_counts()
complaints.plot(kind = "bar")
# Out:
# <Axes: xlabel='Complaint Type'>

# %%
complaint_counts.head(5)
# Out:
# Complaint Type
# Illegal Parking            1508
# Noise - Residential         791
# Noise - Street/Sidewalk     634
# Blocked Driveway            514
# UNSANITARY CONDITION        388
# Name: count, dtype: int64

# %%
top10_complaints = complaint_counts.head(10)
top10_complaints.plot(kind = "bar")
# Out:
# <Axes: xlabel='Complaint Type'>

# %%
complaint_counts.head(10).plot(kind = "bar")
# Out:
# <Axes: xlabel='Complaint Type'>

# %%
calls.shape
# Out:
# (9533, 47)

# %%
calls.shape[1]
# Out:
# 47

# %%
num_calls = calls.shape[0]
num_calls
# Out:
# 9533

# %%
parking_filter = calls["Complaint Type"] == "Illegal Parking"

# %%
parking_filter
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9528    False
# 9529    False
# 9530    False
# 9531    False
# 9532    False
# Name: Complaint Type, Length: 9533, dtype: bool

# %%
parking_filter.sum()
# Out:
# 1508

# %%
num_illegal_parking = parking_filter.sum()
num_illegal_parking
# Out:
# 1508

# %%
num_illegal_parking/num_calls
# Out:
# 0.15818734920801428

# %%
hydrants_filter = calls["Descriptor"] == "Blocked Hydrant"

# %%
hydrants_filter
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9528    False
# 9529    False
# 9530    False
# 9531    False
# 9532    False
# Name: Descriptor, Length: 9533, dtype: bool

# %%
num_blocked_hydrant = hydrants_filter.sum()

# %%
num_blocked_hydrant
# Out:
# 428

# %%
num_blocked_hydrant/num_illegal_parking
# Out:
# 0.2838196286472148

# %% [markdown]
# We will use the 311 service request dataset from Lab 8, which contains information about all complaints and service request calls made to 311 in New York city.
# Write a piece of code that computes the probability that a 311 call involves a club, bar, or restaurant. Such calls have Club/Bar/Restaurant in the Location Type column.

# %% [markdown]
# i) What is the probability that a call is about a club, bar, or restaurant? (Round you answer to 3 decimal places.
#
# ii) That is, your answer should only have three digits after the decimal point.)
# What percentage of calls are about a club, bar, or restaurant?

# %%
calls = pd.read_csv("311_Service_Requests_from_2010_to_Present.csv")

# %%
calls.head(2)
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    58823685  09/15/2023 11:59:57 PM  09/18/2023 11:39:38 AM  DOHMH
# 1    58821637  09/15/2023 11:59:44 PM  09/16/2023 12:25:10 AM   NYPD
#
#                                Agency Name           Complaint Type  \
# 0  Department of Health and Mental Hygiene                   Rodent
# 1          New York City Police Department  Noise - Street/Sidewalk
#
#          Descriptor            Location Type  Incident Zip  \
# 0      Rat Sighting  3+ Family Apt. Building       11213.0
# 1  Loud Music/Party          Street/Sidewalk       10034.0
#
#         Incident Address        Street Name      Cross Street 1  \
# 0      1702 UNION STREET       UNION STREET  SCHENECTADY AVENUE
# 1  108 PARK TERRACE EAST  PARK TERRACE EAST    WEST  217 STREET
#
#      Cross Street 2 Intersection Street 1 Intersection Street 2 Address Type  \
# 0      UTICA AVENUE    SCHENECTADY AVENUE          UTICA AVENUE      ADDRESS
# ...

# %%
calls["Location Type"].value_counts()
# Out:
# Location Type
# Street/Sidewalk                  3251
# RESIDENTIAL BUILDING             1448
# Street                           1164
# Residential Building/House        894
# Sidewalk                          482
# Store/Commercial                  229
# Club/Bar/Restaurant               134
# Park                              108
# Above Address                      89
# Subway                             79
# Park/Playground                    72
# 3+ Family Apt. Building            63
# Business                           48
# 1-2 Family Dwelling                42
# Restaurant/Bar/Deli/Bakery         39
# Mixed Use                          35
# Other (Explain Below)              32
# 3+ Family Apartment Building       30
# Yard                               23
# Commercial Building                15
# Comercial                          15
# Other                              14
# Taxi                               13
# Residential Building               10
# ...

# %%
Restaurant_filter = calls["Location Type"] == "Club/Bar/Restaurant"

# %%
Restaurant_filter
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 9528    False
# 9529    False
# 9530    False
# 9531    False
# 9532    False
# Name: Location Type, Length: 9533, dtype: bool

# %%
num_club_bar_restaurant = Restaurant_filter.sum()

# %%
num_club_bar_restaurant
# Out:
# 134

# %%
num_club_bar_restaurant/num_calls
# Out:
# 0.014056435539704185
