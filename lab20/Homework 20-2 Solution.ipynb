# %% [markdown]
# *Replace this text with your own name and a brief description of what this notebook does.*

# %% [markdown]
# ## Homework 20-2: Correlation and Starbucks drinks
#
# This assignment uses the Starbucks drinks nuitrition dataset from Lab 18.  You will have to repeat the data cleaning steps from the lab in your assignment.
#
# Compute the correlation matrix for all numerical columns in the dataset, and plot it as a heatmap.  Also plot all pairwise scatterplots using the `pairplot()` function in Seaborn.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
drinks = pd.read_csv("../../Data/starbucks-menu-nutrition-drinks.csv",index_col = 0, na_values = ["-"])
drinks = drinks.dropna(axis = 0)
drinks.head()
# Out:
#                                                     Calories  Fat (g)  \
# Cool Lime Starbucks Refreshers™ Beverage                45.0      0.0
# Strawberry Acai Starbucks Refreshers™ Beverage          80.0      0.0
# Very Berry Hibiscus Starbucks Refreshers™ Beverage      60.0      0.0
# Evolution Fresh™ Organic Ginger Limeade                110.0      0.0
# Iced Coffee                                              0.0      0.0
#
#                                                     Carb. (g)  Fiber (g)  \
# Cool Lime Starbucks Refreshers™ Beverage                 11.0        0.0
# Strawberry Acai Starbucks Refreshers™ Beverage           18.0        1.0
# Very Berry Hibiscus Starbucks Refreshers™ Beverage       14.0        1.0
# Evolution Fresh™ Organic Ginger Limeade                  28.0        0.0
# Iced Coffee                                               0.0        0.0
#
#                                                     Protein  Sodium
# ...

# %%
corr_matrix = drinks.corr()
corr_matrix
# Out:
#            Calories   Fat (g)  Carb. (g)  Fiber (g)   Protein    Sodium
# Calories   1.000000  0.756198   0.871283   0.519589  0.774588  0.729955
# Fat (g)    0.756198  1.000000   0.373783   0.390315  0.700098  0.683170
# Carb. (g)  0.871283  0.373783   1.000000   0.442768  0.478745  0.452783
# Fiber (g)  0.519589  0.390315   0.442768   1.000000  0.541957  0.356043
# Protein    0.774588  0.700098   0.478745   0.541957  1.000000  0.805192
# Sodium     0.729955  0.683170   0.452783   0.356043  0.805192  1.000000

# %%
sns.heatmap(corr_matrix)

# %%
sns.pairplot(drinks)

# %% [markdown]
# 1. Which pair of (distinct) columns are the most correlated?
# 2. Which pair of (distinct) columns are the least correlated?
# 3. What is something interesting or unexpected that you notice from a scatter plot above?
#
# Write your answers below.

# %% [markdown]
#  1. The calories and carbs columns are the most correlated.
#  2. The sodium and fiber columns are the least correlated.
#  3. (There is are many good answers to this questions.  What follows is just one example.)  There seems to be a single outlier in many of the scatter plots.  We can find it below by finding the drink with the most fat.

# %%
drinks["Fat (g)"].idxmax()
# Out:
# 'Starbucks® Signature Hot Chocolate'
