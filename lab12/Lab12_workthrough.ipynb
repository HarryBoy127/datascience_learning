# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
calls = pd.read_csv("oct1_oct2_2023_311_Service_Requests_from_2010_to_Present.csv", parse_dates =["Created Date"])
# Out:
# /var/folders/hh/nxh3r3vn2jx97bs11v7tsmd40000gn/T/ipykernel_79330/4277344211.py:1: DtypeWarning: Columns (31) have mixed types. Specify dtype option on import or set low_memory=False.
#   calls = pd.read_csv("oct1_oct2_2023_311_Service_Requests_from_2010_to_Present.csv", parse_dates =["Created Date"])
# /var/folders/hh/nxh3r3vn2jx97bs11v7tsmd40000gn/T/ipykernel_79330/4277344211.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   calls = pd.read_csv("oct1_oct2_2023_311_Service_Requests_from_2010_to_Present.csv", parse_dates =["Created Date"])

# %%
calls.head(3)
# Out:
#    Unique Key        Created Date             Closed Date Agency  \
# 0    58987955 2023-10-02 23:59:56  10/03/2023 01:01:46 AM   NYPD
# 1    59452871 2023-10-02 23:59:52  10/08/2023 12:00:00 AM    HPD
# 2    58993955 2023-10-02 23:59:34  10/03/2023 12:44:23 AM   NYPD
#
#                                          Agency Name        Complaint Type  \
# 0                    New York City Police Department      Blocked Driveway
# 1  Department of Housing Preservation and Develop...  Unsanitary Condition
# 2                    New York City Police Department    Noise - Commercial
#
#          Descriptor        Location Type  Incident Zip     Incident Address  \
# 0         No Access      Street/Sidewalk       11420.0    120-01 111 AVENUE
# 1              Mold            Apartment       11238.0  475 ST MARKS AVENUE
# 2  Loud Music/Party  Club/Bar/Restaurant       10453.0  64 EAST  183 STREET
#
#    ... Bridge Highway Segment   Latitude  Longitude  \
# ...

# %%
sun_filter = calls["Created Date"].dt.day == 1

# %%
sun_calls = calls[sun_filter]

# %%
sun_calls.head(2)
# Out:
#        Unique Key        Created Date             Closed Date Agency  \
# 13406    58985964 2023-10-01 23:59:56  10/02/2023 12:27:35 AM   NYPD
# 13407    58978228 2023-10-01 23:59:52  10/02/2023 01:15:47 AM   NYPD
#
#                            Agency Name               Complaint Type  \
# 13406  New York City Police Department      Noise - Street/Sidewalk
# 13407  New York City Police Department  Non-Emergency Police Matter
#
#          Descriptor               Location Type  Incident Zip  \
# 13406  Loud Talking             Street/Sidewalk       10019.0
# 13407   Trespassing  Residential Building/House       11385.0
#
#              Incident Address  ... Bridge Highway Segment   Latitude  \
# 13406    318 WEST   51 STREET  ...                    NaN  40.763248
# 13407  261 ST NICHOLAS AVENUE  ...                    NaN  40.702225
#
#        Longitude                                 Location Zip Codes  \
# 13406 -73.986467  (40.76324844017083, -73.98646657198002)   12081.0
# ...

# %%
mon_filter = calls["Created Date"].dt.day == 2
mon_calls = calls[mon_filter]
mon_calls.head(3)
# Out:
#    Unique Key        Created Date             Closed Date Agency  \
# 0    58987955 2023-10-02 23:59:56  10/03/2023 01:01:46 AM   NYPD
# 1    59452871 2023-10-02 23:59:52  10/08/2023 12:00:00 AM    HPD
# 2    58993955 2023-10-02 23:59:34  10/03/2023 12:44:23 AM   NYPD
#
#                                          Agency Name        Complaint Type  \
# 0                    New York City Police Department      Blocked Driveway
# 1  Department of Housing Preservation and Develop...  Unsanitary Condition
# 2                    New York City Police Department    Noise - Commercial
#
#          Descriptor        Location Type  Incident Zip     Incident Address  \
# 0         No Access      Street/Sidewalk       11420.0    120-01 111 AVENUE
# 1              Mold            Apartment       11238.0  475 ST MARKS AVENUE
# 2  Loud Music/Party  Club/Bar/Restaurant       10453.0  64 EAST  183 STREET
#
#    ... Bridge Highway Segment   Latitude  Longitude  \
# ...

# %%
sun_calls["Created Date"].dt.hour
# Out:
# 13406    23
# 13407    23
# 13408    23
# 13409    23
# 13410    23
#          ..
# 24690     0
# 24691     0
# 24692     0
# 24693     0
# 24694     0
# Name: Created Date, Length: 11289, dtype: int32

# %%
sun_calls["Created Date"].dt.hour.hist(bins = 30)
# Out:
# <Axes: >

# %%
mon_calls["Created Date"].dt.hour.hist(bins = 30)
# Out:
# <Axes: >

# %%
sun_calls["Created Date"].dt.hour.hist(bins = 30, alpha = 0.5, color = "Blue", density = "True")
mon_calls["Created Date"].dt.hour.hist(bins = 30,alpha = 0.5, color = "red", density = "True")
plt.xlabel("hours")
plt.title( "Total Distribition of complaints")
plt.ylabel("number of complaints")
plt.legend(["Sunday", "Monday"])

# %%
sun_borough_counts = sun_calls["Borough"].value_counts()
sun_borough_counts
# Out:
# Borough
# BROOKLYN         3498
# QUEENS           2885
# MANHATTAN        2482
# BRONX            2065
# STATEN ISLAND     351
# Unspecified         8
# Name: count, dtype: int64

# %%
mon_borough_counts = mon_calls["Borough"].value_counts()
mon_borough_counts
# Out:
# Borough
# BROOKLYN         4594
# MANHATTAN        2850
# QUEENS           2827
# BRONX            2694
# STATEN ISLAND     434
# Unspecified         7
# Name: count, dtype: int64

# %%
borough_counts_df = pd.DataFrame({"sunday":sun_borough_counts,"monday":mon_borough_counts})
borough_counts_df
# Out:
#                sunday  monday
# Borough
# BRONX            2065    2694
# BROOKLYN         3498    4594
# MANHATTAN        2482    2850
# QUEENS           2885    2827
# STATEN ISLAND     351     434
# Unspecified         8       7

# %%
borough_counts_df.plot(kind = "bar")
# Out:
# <Axes: xlabel='Borough'>

# %%
borough_counts_df.plot(kind = "bar", color = ["purple","turquoise"])
# Out:
# <Axes: xlabel='Borough'>

# %%
borough_counts_df.plot(kind = "bar", color = ["purple","turquoise"])
plt.xlabel("borough")
plt.title( "Total Distribition of complaints")
plt.ylabel("number of complaints")
plt.legend(["Sunday", "Monday"])

# %%
norm_sun_borough_counts = sun_calls["Borough"].value_counts(normalize = True)
norm_sun_borough_counts
# Out:
# Borough
# BROOKLYN         0.309859
# QUEENS           0.255559
# MANHATTAN        0.219860
# BRONX            0.182921
# STATEN ISLAND    0.031092
# Unspecified      0.000709
# Name: proportion, dtype: float64

# %%
norm_mon_borough_counts = mon_calls["Borough"].value_counts(normalize = True)
norm_mon_borough_counts
# Out:
# Borough
# BROOKLYN         0.342682
# MANHATTAN        0.212591
# QUEENS           0.210876
# BRONX            0.200955
# STATEN ISLAND    0.032374
# Unspecified      0.000522
# Name: proportion, dtype: float64

# %%
norm_sun_borough_counts.plot(kind = "bar")
# Out:
# <Axes: xlabel='Borough'>

# %%
norm_mon_borough_counts.plot(kind = "bar")
# Out:
# <Axes: xlabel='Borough'>

# %%
before_6am_filter = calls["Created Date"].dt.hour < 6
after_6pm_filter = calls["Created Date"].dt.hour > 18

night_calls = calls[before_6am_filter | after_6pm_filter]
day_calls = calls[~before_6am_filter & ~after_6pm_filter]

night_counts = night_calls["Complaint Type"].value_counts()
day_counts = day_calls["Complaint Type"].value_counts()
night_day_df = pd.DataFrame({"Day":day_counts, "Night": night_counts})

# Plot only the complaints that occur more than 100 times during the day 
# and more than 50 times during the night.
day_top_filter = night_day_df["Day"] > 100
night_top_filter =  night_day_df["Night"] >50
night_day_df[day_top_filter & night_top_filter].plot(kind = "bar")
# Out:
# <Axes: xlabel='Complaint Type'>
