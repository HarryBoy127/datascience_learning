# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
shelter = pd.read_csv("../data/DHS_Daily_Report.csv", parse_dates = ["Date of Census"])

# %%
shelter.head()
# Out:
#   Date of Census  Total Adults in Shelter  Total Children in Shelter  \
# 0     2023-11-15                    56103                      33104
# 1     2023-11-14                    56245                      33126
# 2     2023-11-13                    56281                      33160
# 3     2023-11-12                    56122                      33131
# 4     2023-11-11                    56090                      33136
#
#    Total Individuals in Shelter  Single Adult Men in Shelter  \
# 0                         89207                        15853
# 1                         89371                        15930
# 2                         89441                        15916
# 3                         89253                        15835
# 4                         89226                        15835
#
#    Single Adult Women in Shelter  Total Single Adults in Shelter  \
# 0                           5083                           20936
# ...

# %%
shelter.plot(x= "Date of Census").legend(bbox_to_anchor=(1,1))

# %%
shelter["Total Adults in Shelter"]/ shelter["Total Individuals in Shelter"]
# Out:
# 0       0.628908
# 1       0.629343
# 2       0.629253
# 3       0.628797
# 4       0.628628
#           ...
# 3675    0.570781
# 3676    0.569845
# 3677    0.570295
# 3678    0.570859
# 3679    0.570914
# Length: 3680, dtype: float64

# %%
shelter["Proportion of Adults"] = shelter["Total Adults in Shelter"]/shelter["Total Individuals in Shelter"]

# %%
shelter
# Out:
#      Date of Census  Total Adults in Shelter  Total Children in Shelter  \
# 0        2023-11-15                    56103                      33104
# 1        2023-11-14                    56245                      33126
# 2        2023-11-13                    56281                      33160
# 3        2023-11-12                    56122                      33131
# 4        2023-11-11                    56090                      33136
# ...             ...                      ...                        ...
# 3675     2013-08-25                    28458                      21400
# 3676     2013-08-24                    28274                      21343
# 3677     2013-08-23                    28257                      21291
# 3678     2013-08-22                    28366                      21324
# 3679     2013-08-21                    28359                      21314
#
#       Total Individuals in Shelter  Single Adult Men in Shelter  \
# ...

# %%
shelter.plot(x ="Total Adults in Shelter", y="Total Individual in Shelter")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total Individual in Shelter'
#
# The above exception was the direct cause of the following exception:
#
# ...
