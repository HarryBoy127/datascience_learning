# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
taxi = pd.read_csv("2021_Green_Taxi_Trip_Data.csv", parse_dates =["lpep_pickup_datetime", "lpep_dropoff_datetime"])
# Out:
# /var/folders/hh/nxh3r3vn2jx97bs11v7tsmd40000gn/T/ipykernel_1777/3812648211.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   taxi = pd.read_csv("2021_Green_Taxi_Trip_Data.csv", parse_dates =["lpep_pickup_datetime", "lpep_dropoff_datetime"])
# /var/folders/hh/nxh3r3vn2jx97bs11v7tsmd40000gn/T/ipykernel_1777/3812648211.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   taxi = pd.read_csv("2021_Green_Taxi_Trip_Data.csv", parse_dates =["lpep_pickup_datetime", "lpep_dropoff_datetime"])

# %%
taxi
# Out:
#       VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0            2  2021-09-01 00:00:11   2021-09-01 00:01:39                  N
# 1            2  2021-09-01 00:00:26   2021-09-01 00:09:38                  N
# 2            2  2021-09-01 00:01:27   2021-09-01 00:23:14                  N
# 3            1  2021-09-01 00:01:31   2021-09-01 00:15:14                  N
# 4            2  2021-09-01 00:02:08   2021-09-01 00:24:51                  N
# ...        ...                  ...                   ...                ...
# 2868         2  2021-09-01 23:10:27   2021-09-01 23:32:51                  N
# 2869         2  2021-09-01 23:34:20   2021-09-01 23:48:46                  N
# 2870         2  2021-09-01 23:38:02   2021-09-01 23:46:55                  N
# 2871         2  2021-09-01 23:53:27   2021-09-02 00:06:29                  N
# 2872         2  2021-09-01 23:58:26   2021-09-02 00:10:09                  N
#
# ...

# %%
taxi["trip_distance"].hist(bins=20)
# Out:
# <Axes: >

# %%
taxi["trip_distance"].hist(bins = 20)
plt.xlabel("trip distance")
plt.ylabel("trip")
plt.show()

# %%
taxi["passenger_count"].hist(bins = 20)
# Out:
# <Axes: >

# %% [markdown]
# This assignment will use the green taxi trip dataset you downloaded and used in Labs 3 and 4.
# Write a piece of code that generates a histogram of the tip amount, which is the tip paid by credit card. It does not include cash tips.
# Label the x and y axes of your plot and add a title.

# %%
taxi["tip_amount"].hist(bins = 30)
plt.xlabel("tip_amount")
plt.ylabel("no of trip")
plt.show()

# %%
taxi["tip_amount"].value_counts()
# Out:
# tip_amount
# 0.00    1852
# 3.00      56
# 1.00      49
# 2.00      38
# 5.00      27
#         ...
# 6.60       1
# 8.12       1
# 8.58       1
# 5.21       1
# 5.89       1
# Name: count, Length: 377, dtype: int64
